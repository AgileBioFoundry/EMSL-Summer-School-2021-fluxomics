# %% [markdown]
# # Flux observability
#
#  [Crown and Antoniewicz, 2012](http://linkinghub.elsevier.com/retrieve/pii/S1096717611001273)  provide an algorithm for determining which fluxes are observable given a selection of tracers for 13C-metabolic flux analysis. Consider the network in figure 1.  In this system, metabolite $A$ is the substrate, metabolite $E$ is the product, and the intermediate metabolites $B, C$ and $D$ are assumed to be at metabolic and isotopic steady state. This network has two free fluxes, namely the substrate consumption rate $v_1$ and the flux of the reversible cleavage/condensation reaction $v_4$. We would like to determine flux $v_4$ based solely on the measurement of the Mass Isotope Distribution (MID) of $E$ and a known uptake rate of $A$. Three key questions that we would like to answer are:
#
# 1. Which labeling pattern(s) of $A$ can be used to resolve flux $v_4$?
# 2. Are there certain tracers that will never allow flux $v_4$ to be observed?
# 3. Is there a rational criterion that can be used a priori to identify good tracers from poor tracers?
#
# ## Definitions
# * **Isotopic Labeling State** represents  a substrate with a mixture of labels where the location of each labeled atom is known.   To fully specify the isotopic labeling state of the  mixture, both percentage of each component of the mixture and which atoms are labeled in each component must be described.
# * **Mass Isotopomer Distribution**  represents a substrate witha mixture of labels where the location of each labeled atom is not known. For a molecule with $n$ atoms, $M_0,M_1,\ldots,M_n$ specifies the percentage of atoms that are unlabeled, 1-labeled, up to fully labeled.
# * **Elementary Metabolite Units (EMU)** are distinct subsets of the compound's atoms.  There are 7 EMU's for a 3-atom metabolite $A$ shown in the figure from [Antoniewicz 2007](http://linkinghub.elsevier.com/retrieve/pii/S109671760600084X) below. The subscript in the first column and the shaded areas in the second column denote the atoms that are included in the EMU. The EMU size is the number of atoms included in the EMU. ![EMU_definitions](EMU_definition.png)
# * An **EMU network** is a set of EMU's and the transitions between them.  The network can be restricted to EMUs of a particular size (Figure 3A), or it can be combined into a larger network composed of EMU's of all sizes (Figure 3B).
# *  **EMU basis vector** can be viewed as a unique way for assembling substrate EMUs to form the product. By definition, EMU basis vectors have the same EMU size as the product. Ultimately, one can interpret the Mass Isotopic Distribution (MID) of the product as a linear combination of EMU basis vector MIDs, where the coefficients are solely a function of free fluxes. The coefficients quantify the fractional contribution of each EMU basis vector to the product. Thus, by definition, the sum of the coefficients must equal one.
# * In addition to the EMU basis vector, Crown et al also define an **EMU pathway**. Each EMU basis vector specifies a unique EMU pathway from substrate(s) to product.
# * An **Elementary mode (ELMO)** of a network is a minimal cardinality set of reactions that form a steady-state. Minimal cardinality means that no steady-state flux distribution can be a subset of an elementary mode.  The set of elementary modes forms a basis for steady-state flux space.
# * Assertion: The elementary modes of the EMU network are the EMU pathways. Evidence for this assertion is provided below.

# %%
import gurobipy
from cobra.util.solver import linear_reaction_coefficients
from IPython.display import display, Image, Markdown, Latex, HTML
import pandas as pd
import numpy as np
import scipy, sympy
from cobra import Metabolite, Reaction, Model
import cobra
import sys, re,os
sys.path.append(os.path.join(os.environ['HOME'],'Projects/src'))
from pyefm import calculate_elementary_modes, calculate_minimum_cut_sets, utils
from d3flux import flux_map
from IPython.display import display, Image, SVG, Markdown,Latex, HTML
import sympy 
from itertools import chain
from cobra.flux_analysis.geometric import geometric_fba
from pyemu import extract_emu_network, get_em_description, display_rxns

# %% [markdown]
# # Read in Neurospora  EMU Network

# %%
emu_network = {}
emu_network['full'] = cobra.io.load_json_model(filename='Neurospora_EMU_network_size_{}.json'.format('full'))
emu_pwys = {}
for size in range(1,8):
    emu_network[size] = extract_emu_network( emu_network['full'], size )
    print("Number of EMU reactions of size {}: {}".format(size, len(emu_network[size].reactions)))
    cobra.io.save_json_model(emu_network[size],filename='Neurospora_EMU_network_size_{}.json'.format(size),
                             sort=True, pretty=True)
emu_network['full'].solver
# Out:
# Number of EMU reactions of size 1: 797
# Number of EMU reactions of size 2: 541
# Number of EMU reactions of size 3: 301
# Number of EMU reactions of size 4: 158
# Number of EMU reactions of size 5: 69
# Number of EMU reactions of size 6: 27
# Number of EMU reactions of size 7: 5

# %% [markdown]
# # Calculate active fluxes of EMU network from glucose to carbon dioxide

# %%
emu_network['full'].solver = 'gurobi'
#emu_network['full'].objective='EX_co2_e_1'
soln = emu_network['full'].optimize().to_frame()
soln['equation'] = [emu_network['full'].reactions.get_by_id(rxn).reaction for rxn in soln.index]
active_fluxes = soln[soln['fluxes'] !=0]
active_fluxes
# Out:
#               fluxes  reduced_costs               equation
# 6PGLter_b_8     10.0            0.0    6pgl_r_1 --> 6pgl_1
# ACL_11          10.0            0.0      cit_5 --> accoa_1
# ACONT_f_19      20.0            0.0       cit_6 --> icit_6
# CITtam_b_18     10.0            0.0      cit_m_5 --> cit_5
# CITtam_b_21     20.0            0.0      cit_m_6 --> cit_6
# CO2t_b_0        60.0            0.0      co2_1 --> co2_e_1
# CO2tm_b_0       40.0            0.0      co2_m_1 --> co2_1
# CSm_15          10.0            0.0  accoa_m_2 --> cit_m_5
# CSm_2           20.0            0.0  accoa_m_1 --> cit_m_6
# ENO_f_2         20.0            0.0        2pg_1 --> pep_1
# ENO_f_4         10.0            0.0        2pg_3 --> pep_3
# ENO_f_5         20.0            0.0        2pg_2 --> pep_2
# EX_co2_e_1      60.0            0.0           co2_e_1 -->
# EX_glc-D_e_1    10.0            2.0          --> glc-D_e_1
# EX_glc-D_e_2    10.0            2.0          --> glc-D_e_2
# EX_glc-D_e_3    10.0            2.0          --> glc-D_e_3
# EX_glc-D_e_4    10.0            2.0          --> glc-D_e_4
# EX_glc-D_e_5    10.0            2.0          --> glc-D_e_5
# EX_glc-D_e_6    10.0            2.0          --> glc-D_e_6
# FBA_f_0         10.0            0.0       fdp_6 --> dhap_3
# FBA_f_10        10.0            0.0        fdp_3 --> g3p_1
# FBA_f_4         10.0            0.0        fdp_2 --> g3p_2
# FUM_f_8         20.0            0.0      fum_1 --> mal-L_1
# G6PDH2er_9      10.0            0.0   g6p_r_1 --> 6pgl_r_1
# G6Pter_f_11     10.0            0.0      g6p_1 --> g6p_r_1
# GAPD_f_0        20.0            0.0      g3p_1 --> 13dpg_1
# GAPD_f_1        20.0            0.0      g3p_2 --> 13dpg_2
# GAPD_f_5        10.0            0.0      g3p_3 --> 13dpg_3
# GLCt1_1         10.0            0.0  glc-D_e_4 --> glc-D_4
# GLCt1_10        10.0            0.0  glc-D_e_6 --> glc-D_6
# ...              ...            ...                    ...
# PDHm_2          40.0            0.0    pyr_m_1 --> co2_m_1
# PFK_10          10.0            0.0        f6p_6 --> fdp_6
# PFK_4           10.0            0.0        f6p_2 --> fdp_2
# PFK_9           10.0            0.0        f6p_3 --> fdp_3
# PGI_f_0         10.0            0.0        g6p_5 --> f6p_5
# PGI_f_11        10.0            0.0        g6p_2 --> f6p_2
# PGI_f_3         10.0            0.0        g6p_6 --> f6p_6
# PGI_f_6         10.0            0.0        g6p_4 --> f6p_4
# PGI_f_8         10.0            0.0        g6p_3 --> f6p_3
# PGK_b_1         20.0            0.0      13dpg_2 --> 3pg_2
# PGK_b_3         20.0            0.0      13dpg_1 --> 3pg_1
# PGK_b_5         10.0            0.0      13dpg_3 --> 3pg_3
# PGL_10          10.0            0.0      6pgl_1 --> 6pgc_1
# PGM_b_1         10.0            0.0        3pg_3 --> 2pg_3
# PGM_b_3         20.0            0.0        3pg_2 --> 2pg_2
# PGM_b_5         20.0            0.0        3pg_1 --> 2pg_1
# PPCK_0          10.0            0.0        oaa_4 --> co2_1
# PPCK_4          20.0            0.0        oaa_1 --> pep_1
# PYK_0           20.0            0.0        pep_2 --> pyr_2
# PYK_1           10.0            0.0        pep_3 --> pyr_3
# PYK_4           40.0            0.0        pep_1 --> pyr_1
# PYRt2m_f_1      20.0            0.0      pyr_2 --> pyr_m_2
# PYRt2m_f_2      40.0            0.0      pyr_1 --> pyr_m_1
# PYRt2m_f_5      10.0            0.0      pyr_3 --> pyr_m_3
# SUCD1m_f_7      20.0            0.0   succ_m_1 --> fum_m_1
# SUCFUMtm_18     20.0            0.0    succ_1 --> succ_m_1
# SUCFUMtm_9      20.0            0.0      fum_m_1 --> fum_1
# TA1_f_6         10.0            0.0        f6p_5 --> g3p_2
# TA1_f_8         10.0            0.0        f6p_4 --> g3p_1
# TPI_f_4         10.0            0.0       dhap_3 --> g3p_3
#
# [77 rows x 3 columns]

# %% [markdown]
# # Calculate EMU pathways of active fluxes

# %%
glc_to_co2_model = cobra.Model('glc_to_co2')
glc_to_co2_model.add_reactions([emu_network['full'].reactions.get_by_id(rxn)
                            for rxn in active_fluxes.index])
glc_to_co2_pwys =  calculate_elementary_modes( glc_to_co2_model,verbose=False,java_args='-Xmx1g')
glc_to_co2_pwys.to_csv('yeast_EMU_pathways_size_{}.csv'.format('full'))
HTML(glc_to_co2_pwys.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>6PGLter_b_8</th>
#       <th>ACL_11</th>
#       <th>ACONT_f_19</th>
#       <th>CITtam_b_18</th>
#       <th>CITtam_b_21</th>
#       <th>CO2t_b_0</th>
#       <th>CO2tm_b_0</th>
#       <th>CSm_15</th>
#       <th>CSm_2</th>
#       <th>ENO_f_2</th>
#       <th>ENO_f_4</th>
#       <th>ENO_f_5</th>
#       <th>EX_co2_e_1</th>
#       <th>EX_glc-D_e_1</th>
#       <th>EX_glc-D_e_2</th>
#       <th>EX_glc-D_e_3</th>
#       <th>EX_glc-D_e_4</th>
#       <th>EX_glc-D_e_5</th>
#       <th>EX_glc-D_e_6</th>
#       <th>FBA_f_0</th>
#       <th>FBA_f_10</th>
#       <th>FBA_f_4</th>
#       <th>FUM_f_8</th>
#       <th>G6PDH2er_9</th>
#       <th>G6Pter_f_11</th>
#       <th>GAPD_f_0</th>
#       <th>GAPD_f_1</th>
#       <th>GAPD_f_5</th>
#       <th>GLCt1_1</th>
#       <th>GLCt1_10</th>
#       <th>GLCt1_4</th>
#       <th>GLCt1_6</th>
#       <th>GLCt1_7</th>
#       <th>GLCt1_8</th>
#       <th>GND_5</th>
#       <th>HEX1_11</th>
#       <th>HEX1_12</th>
#       <th>HEX1_2</th>
#       <th>HEX1_3</th>
#       <th>HEX1_6</th>
#       <th>HEX1_9</th>
#       <th>ICL_1</th>
#       <th>MALS_1</th>
#       <th>MDH_f_0</th>
#       <th>MDH_f_6</th>
#       <th>PDHm_0</th>
#       <th>PDHm_1</th>
#       <th>PDHm_2</th>
#       <th>PFK_10</th>
#       <th>PFK_4</th>
#       <th>PFK_9</th>
#       <th>PGI_f_0</th>
#       <th>PGI_f_11</th>
#       <th>PGI_f_3</th>
#       <th>PGI_f_6</th>
#       <th>PGI_f_8</th>
#       <th>PGK_b_1</th>
#       <th>PGK_b_3</th>
#       <th>PGK_b_5</th>
#       <th>PGL_10</th>
#       <th>PGM_b_1</th>
#       <th>PGM_b_3</th>
#       <th>PGM_b_5</th>
#       <th>PPCK_0</th>
#       <th>PPCK_4</th>
#       <th>PYK_0</th>
#       <th>PYK_1</th>
#       <th>PYK_4</th>
#       <th>PYRt2m_f_1</th>
#       <th>PYRt2m_f_2</th>
#       <th>PYRt2m_f_5</th>
#       <th>SUCD1m_f_7</th>
#       <th>SUCFUMtm_18</th>
#       <th>SUCFUMtm_9</th>
#       <th>TA1_f_6</th>
#       <th>TA1_f_8</th>
#       <th>TPI_f_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EM1</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>EM2</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>EM3</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>EM4</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>EM5</th>
#       <td>0.0<

# %%
em_model = {}

for em in glc_to_co2_pwys.index:
    em_model[em] = cobra.Model(em)
    em_model[em].add_reactions([glc_to_co2_model.reactions.get_by_id(rxn)
                                for rxn in glc_to_co2_pwys.columns
                                   if glc_to_co2_pwys.loc[em,rxn] != 0])
    display(Markdown('### EMU Pathway {} ({})\n'.format(em, get_em_description(glc_to_co2_pwys.loc[em]))))
    display(flux_map(em_model[em],
                     display_name_format=lambda x: str(x.id),
                     flux_dict={rxn.id: glc_to_co2_pwys.loc[em,rxn.id] 
                            for rxn in em_model[em].reactions}))
# Out:
# ### EMU Pathway EM1 (glc-D_e_3 --> co2_e_1)
# <div id="d3flux007">
#
# </div>
# <div id="d3flux007_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux007model = {"metabolites": [{"id": "co2_1", "name": "co", "compartment": "", "notes": {"map_info": {"display_name": "co2_1"}}}, {"id": "co2_e_1", "name": "co2_e", "compartment": "", "notes": {"map_info": {"display_name": "co2_e_1"}}}, {"id": "co2_m_1", "name": "co2_m", "compartment": "", "notes": {"map_info": {"display_name": "co2_m_1"}}}, {"id": "pep_1", "name": "pep", "compartment": "", "notes": {"map_info": {"display_name": "pep_1"}}}, {"id": "2pg_1", "name": "2pg", "compartment": "", "notes": {"map_info": {"display_name": "2pg_1"}}}, {"id": "glc-D_e_3", "name": "glc-D_e", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_e_3"}}}, {"id": "fdp_3", "name": "fdp", "compartment": "", "notes": {"map_info": {"display_name": "fdp_3"}}}, {"id": "g3p_1", "name": "g3p", "compartment": "", "notes": {"map_info": {"display_name": "g3p_1"}}}, {"id": "13dpg_1", "name": "13dpg", "compartment": "", "notes": {"map_info": {"display_name": "13dpg_1"}}}, {"id": "glc-D_3", "name": "glc-D", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_3"}}}, {"id": "g6p_3", "name": "g6p", "compartment": "", "notes": {"map_info": {"display_name": "g6p_3"}}}, {"id": "pyr_m_1", "name": "pyr_m", "compartment": "", "notes": {"map_info": {"display_name": "pyr_m_1"}}}, {"id": "f6p_3", "name": "f6p", "compartment": "", "notes": {"map_info": {"display_name": "f6p_3"}}}, {"id": "3pg_1", "name": "3pg", "compartment": "", "notes": {"map_info": {"display_name": "3pg_1"}}}, {"id": "pyr_1", "name": "pyr", "compartment": "", "notes": {"map_info": {"display_name": "pyr_1"}}}], "reactions": [{"id": "CO2t_b_0", "name": "", "metabolites": {"co2_1": -1, "co2_e_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2tm_b_0", "name": "", "metabolites": {"co2_1": 1, "co2_m_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "ENO_f_2", "name": "", "metabolites": {"2pg_1": -1, "pep_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "EX_co2_e_1", "name": "", "metabolites": {"co2_e_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "EX_glc-D_e_3", "name": "", "metabolites": {"glc-D_e_3": 1}, "lower_bound": 0, "upper_bound": 10, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "FBA_f_10", "name": "", "metabolites": {"fdp_3": -1, "g3p_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "GAPD_f_0", "name": "", "metabolites": {"13dpg_1": 1, "g3p_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "GLCt1_7", "name": "", "metabolites": {"glc-D_3": 1, "glc-D_e_3": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "HEX1_9", "name": "", "metabolites": {"g6p_3": 1, "glc-D_3": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PDHm_2", "name": "", "metabolites": {"co2_m_1": 1, "pyr_m_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PFK_9", "name": "", "metabolites": {"f6p_3": -1, "fdp_3": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PGI_f_8", "name": "", "metabolites": {"f6p_3": 1, "g6p_3": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_r ...
#
# require.config({
#   paths: {
#     d3: "https://d3js.org/d3.v3.min",
#     cola: "http://marvl.infotech.monash.edu/webcola/cola.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#   },
#   shim: {
#     'cola': {
#       exports: 'cola'
#     }
#   }
# });
#
# require(["cola", "d3", "math", "FileSaver"], function (cola, d3, math, FileSaver) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 1028,
#     height = 768;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       // .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#       //         "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .range(["#bbb", "#d62728",
#         "#eb6a9b",
#         "#6f3589",
#         "#f18572",
#         "#246035",
#         "#009fea",
#         "#83522b",
#         "#29378a",
#         "#989033"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = cola.d3adaptor()
#       .linkDistance(30)
#       .size([width, height]);
#     // var force = d3.layout.force()
#     //   .linkDistance(30)
#     //   .charge(-100)
#     //   .chargeDistance(400)
#     //   .gravity(.015)
#     //   .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux007").append("svg")
#         .attr("viewBox", "0 0 1028 768")
#         .attr("style", "display:block;margin:auto;width:100%");
#     } else {
#       var svg = d3.select("#d3flux007").select("svg");
#     }
#
#     // Append the CSS styles
#     svg.append("style").text(".node.rxn{fill:#ffa319}.node.rxn.hidden{fill:none;stroke:none;stroke-width:0}.link{fill:none;stroke-linecap:round}text.nodelabel{font-size:12pt;fill:#555;font-family:Arial}text.nodelabel.cofactor{font-size:9.6pt;fill:#789}text.nodelabel.rxn{fill:#a9a9a9;f
# ### EMU Pathway EM2 (glc-D_e_4 --> co2_e_1)
# <div id="d3flux008">
#
# </div>
# <div id="d3flux008_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux008model = {"metabolites": [{"id": "co2_1", "name": "co", "compartment": "", "notes": {"map_info": {"display_name": "co2_1"}}}, {"id": "co2_e_1", "name": "co2_e", "compartment": "", "notes": {"map_info": {"display_name": "co2_e_1"}}}, {"id": "co2_m_1", "name": "co2_m", "compartment": "", "notes": {"map_info": {"display_name": "co2_m_1"}}}, {"id": "pep_1", "name": "pep", "compartment": "", "notes": {"map_info": {"display_name": "pep_1"}}}, {"id": "2pg_1", "name": "2pg", "compartment": "", "notes": {"map_info": {"display_name": "2pg_1"}}}, {"id": "glc-D_e_4", "name": "glc-D_e", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_e_4"}}}, {"id": "13dpg_1", "name": "13dpg", "compartment": "", "notes": {"map_info": {"display_name": "13dpg_1"}}}, {"id": "g3p_1", "name": "g3p", "compartment": "", "notes": {"map_info": {"display_name": "g3p_1"}}}, {"id": "glc-D_4", "name": "glc-D", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_4"}}}, {"id": "g6p_4", "name": "g6p", "compartment": "", "notes": {"map_info": {"display_name": "g6p_4"}}}, {"id": "pyr_m_1", "name": "pyr_m", "compartment": "", "notes": {"map_info": {"display_name": "pyr_m_1"}}}, {"id": "f6p_4", "name": "f6p", "compartment": "", "notes": {"map_info": {"display_name": "f6p_4"}}}, {"id": "3pg_1", "name": "3pg", "compartment": "", "notes": {"map_info": {"display_name": "3pg_1"}}}, {"id": "pyr_1", "name": "pyr", "compartment": "", "notes": {"map_info": {"display_name": "pyr_1"}}}], "reactions": [{"id": "CO2t_b_0", "name": "", "metabolites": {"co2_1": -1, "co2_e_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2tm_b_0", "name": "", "metabolites": {"co2_1": 1, "co2_m_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "ENO_f_2", "name": "", "metabolites": {"2pg_1": -1, "pep_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "EX_co2_e_1", "name": "", "metabolites": {"co2_e_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "EX_glc-D_e_4", "name": "", "metabolites": {"glc-D_e_4": 1}, "lower_bound": 0, "upper_bound": 10, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "GAPD_f_0", "name": "", "metabolites": {"13dpg_1": 1, "g3p_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "GLCt1_1", "name": "", "metabolites": {"glc-D_4": 1, "glc-D_e_4": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "HEX1_2", "name": "", "metabolites": {"g6p_4": 1, "glc-D_4": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PDHm_2", "name": "", "metabolites": {"co2_m_1": 1, "pyr_m_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PGI_f_6", "name": "", "metabolites": {"f6p_4": 1, "g6p_4": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PGK_b_3", "name": "", "metabolites": {"13dpg_1": -1, "3pg_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PGM_b_5", "name": "", "metabolites": {"2pg_1": 1, "3pg_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PYK_4", "name": " ...
#
# require.config({
#   paths: {
#     d3: "https://d3js.org/d3.v3.min",
#     cola: "http://marvl.infotech.monash.edu/webcola/cola.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#   },
#   shim: {
#     'cola': {
#       exports: 'cola'
#     }
#   }
# });
#
# require(["cola", "d3", "math", "FileSaver"], function (cola, d3, math, FileSaver) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 1028,
#     height = 768;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       // .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#       //         "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .range(["#bbb", "#d62728",
#         "#eb6a9b",
#         "#6f3589",
#         "#f18572",
#         "#246035",
#         "#009fea",
#         "#83522b",
#         "#29378a",
#         "#989033"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = cola.d3adaptor()
#       .linkDistance(30)
#       .size([width, height]);
#     // var force = d3.layout.force()
#     //   .linkDistance(30)
#     //   .charge(-100)
#     //   .chargeDistance(400)
#     //   .gravity(.015)
#     //   .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux008").append("svg")
#         .attr("viewBox", "0 0 1028 768")
#         .attr("style", "display:block;margin:auto;width:100%");
#     } else {
#       var svg = d3.select("#d3flux008").select("svg");
#     }
#
#     // Append the CSS styles
#     svg.append("style").text(".node.rxn{fill:#ffa319}.node.rxn.hidden{fill:none;stroke:none;stroke-width:0}.link{fill:none;stroke-linecap:round}text.nodelabel{font-size:12pt;fill:#555;font-family:Arial}text.nodelabel.cofactor{font-size:9.6pt;fill:#789}text.nodelabel.rxn{fill:#a9a9a9;font-size:9.6pt;font-style:italic}marker.inactive,.node.inactive,text.inactive{fill-opacity:1.0}.link.inactive{stroke-opacity:1.0}");
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux008_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control
# ### EMU Pathway EM3 (glc-D_e_6 --> co2_e_1)
# <div id="d3flux009">
#
# </div>
# <div id="d3flux009_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux009model = {"metabolites": [{"id": "cit_5", "name": "cit", "compartment": "", "notes": {"map_info": {"display_name": "cit_5"}}}, {"id": "accoa_1", "name": "accoa", "compartment": "", "notes": {"map_info": {"display_name": "accoa_1"}}}, {"id": "cit_m_5", "name": "cit_m", "compartment": "", "notes": {"map_info": {"display_name": "cit_m_5"}}}, {"id": "co2_1", "name": "co", "compartment": "", "notes": {"map_info": {"display_name": "co2_1"}}}, {"id": "co2_e_1", "name": "co2_e", "compartment": "", "notes": {"map_info": {"display_name": "co2_e_1"}}}, {"id": "accoa_m_2", "name": "accoa_m", "compartment": "", "notes": {"map_info": {"display_name": "accoa_m_2"}}}, {"id": "2pg_3", "name": "2pg", "compartment": "", "notes": {"map_info": {"display_name": "2pg_3"}}}, {"id": "pep_3", "name": "pep", "compartment": "", "notes": {"map_info": {"display_name": "pep_3"}}}, {"id": "glc-D_e_6", "name": "glc-D_e", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_e_6"}}}, {"id": "fdp_6", "name": "fdp", "compartment": "", "notes": {"map_info": {"display_name": "fdp_6"}}}, {"id": "dhap_3", "name": "dhap", "compartment": "", "notes": {"map_info": {"display_name": "dhap_3"}}}, {"id": "13dpg_3", "name": "13dpg", "compartment": "", "notes": {"map_info": {"display_name": "13dpg_3"}}}, {"id": "g3p_3", "name": "g3p", "compartment": "", "notes": {"map_info": {"display_name": "g3p_3"}}}, {"id": "glc-D_6", "name": "glc-D", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_6"}}}, {"id": "g6p_6", "name": "g6p", "compartment": "", "notes": {"map_info": {"display_name": "g6p_6"}}}, {"id": "mal-L_4", "name": "mal-L", "compartment": "", "notes": {"map_info": {"display_name": "mal-L_4"}}}, {"id": "oaa_4", "name": "oaa", "compartment": "", "notes": {"map_info": {"display_name": "oaa_4"}}}, {"id": "pyr_m_3", "name": "pyr_m", "compartment": "", "notes": {"map_info": {"display_name": "pyr_m_3"}}}, {"id": "f6p_6", "name": "f6p", "compartment": "", "notes": {"map_info": {"display_name": "f6p_6"}}}, {"id": "3pg_3", "name": "3pg", "compartment": "", "notes": {"map_info": {"display_name": "3pg_3"}}}, {"id": "pyr_3", "name": "pyr", "compartment": "", "notes": {"map_info": {"display_name": "pyr_3"}}}], "reactions": [{"id": "ACL_11", "name": "", "metabolites": {"accoa_1": 1, "cit_5": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CITtam_b_18", "name": "", "metabolites": {"cit_5": 1, "cit_m_5": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2t_b_0", "name": "", "metabolites": {"co2_1": -1, "co2_e_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CSm_15", "name": "", "metabolites": {"accoa_m_2": -1, "cit_m_5": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "ENO_f_4", "name": "", "metabolites": {"2pg_3": -1, "pep_3": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "EX_co2_e_1", "name": "", "metabolites": {"co2_e_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "EX_glc-D_e_6", "name": "", "metabolites": {"glc-D_e_6": 1}, "lower_bound": 0, "upper_bound": 10, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "FBA_f_0", "name": "", "metabolites": {"dhap_3": 1, "fdp_6": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "GAPD_f_5", "name": "", "metabolites": {"13dpg_3": 1, "g3p_3": -1}, "lower_bound": 0, "upp ...
#
# require.config({
#   paths: {
#     d3: "https://d3js.org/d3.v3.min",
#     cola: "http://marvl.infotech.monash.edu/webcola/cola.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#   },
#   shim: {
#     'cola': {
#       exports: 'cola'
#     }
#   }
# });
#
# require(["cola", "d3", "math", "FileSaver"], function (cola, d3, math, FileSaver) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 1028,
#     height = 768;
#
#     // var color = d3.scale.category1
# ### EMU Pathway EM4 (glc-D_e_5 --> co2_e_1)
# <div id="d3flux010">
#
# </div>
# <div id="d3flux010_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux010model = {"metabolites": [{"id": "icit_6", "name": "icit", "compartment": "", "notes": {"map_info": {"display_name": "icit_6"}}}, {"id": "cit_6", "name": "cit", "compartment": "", "notes": {"map_info": {"display_name": "cit_6"}}}, {"id": "cit_m_6", "name": "cit_m", "compartment": "", "notes": {"map_info": {"display_name": "cit_m_6"}}}, {"id": "co2_1", "name": "co", "compartment": "", "notes": {"map_info": {"display_name": "co2_1"}}}, {"id": "co2_e_1", "name": "co2_e", "compartment": "", "notes": {"map_info": {"display_name": "co2_e_1"}}}, {"id": "co2_m_1", "name": "co2_m", "compartment": "", "notes": {"map_info": {"display_name": "co2_m_1"}}}, {"id": "accoa_m_1", "name": "accoa_m", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "accoa_m_1"}}}, {"id": "pep_2", "name": "pep", "compartment": "", "notes": {"map_info": {"display_name": "pep_2"}}}, {"id": "2pg_2", "name": "2pg", "compartment": "", "notes": {"map_info": {"display_name": "2pg_2"}}}, {"id": "glc-D_e_5", "name": "glc-D_e", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_e_5"}}}, {"id": "mal-L_1", "name": "mal-L", "compartment": "", "notes": {"map_info": {"display_name": "mal-L_1"}}}, {"id": "fum_1", "name": "fum", "compartment": "", "notes": {"map_info": {"display_name": "fum_1"}}}, {"id": "13dpg_2", "name": "13dpg", "compartment": "", "notes": {"map_info": {"display_name": "13dpg_2"}}}, {"id": "g3p_2", "name": "g3p", "compartment": "", "notes": {"map_info": {"display_name": "g3p_2"}}}, {"id": "glc-D_5", "name": "glc-D", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_5"}}}, {"id": "g6p_5", "name": "g6p", "compartment": "", "notes": {"map_info": {"display_name": "g6p_5"}}}, {"id": "succ_1", "name": "succ", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "succ_1"}}}, {"id": "oaa_1", "name": "oaa", "compartment": "", "notes": {"map_info": {"display_name": "oaa_1"}}}, {"id": "pyr_m_2", "name": "pyr_m", "compartment": "", "notes": {"map_info": {"display_name": "pyr_m_2"}}}, {"id": "pyr_m_1", "name": "pyr_m", "compartment": "", "notes": {"map_info": {"display_name": "pyr_m_1"}}}, {"id": "f6p_5", "name": "f6p", "compartment": "", "notes": {"map_info": {"display_name": "f6p_5"}}}, {"id": "3pg_2", "name": "3pg", "compartment": "", "notes": {"map_info": {"display_name": "3pg_2"}}}, {"id": "pep_1", "name": "pep", "compartment": "", "notes": {"map_info": {"display_name": "pep_1"}}}, {"id": "pyr_2", "name": "pyr", "compartment": "", "notes": {"map_info": {"display_name": "pyr_2"}}}, {"id": "pyr_1", "name": "pyr", "compartment": "", "notes": {"map_info": {"display_name": "pyr_1"}}}, {"id": "succ_m_1", "name": "succ_m", "compartment": "", "notes": {"map_info": {"display_name": "succ_m_1"}}}, {"id": "fum_m_1", "name": "fum_m", "compartment": "", "notes": {"map_info": {"display_name": "fum_m_1"}}}], "reactions": [{"id": "ACONT_f_19", "name": "", "metabolites": {"cit_6": -1, "icit_6": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CITtam_b_21", "name": "", "metabolites": {"cit_6": 1, "cit_m_6": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2t_b_0", "name": "", "metabolites": {"co2_1": -1, "co2_e_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2tm_b_0", "name": "", "metabolites": {"co2_1": 1, "co2_m_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CSm_2", "name": "", "metabolites": {"accoa_m_1": -1, "cit_m_6": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "ENO_f_5", "name": "", "metabolites": {"2pg_2":  ...
# ### EMU Pathway EM5 (glc-D_e_2 --> co2_e_1)
# <div id="d3flux011">
#
# </div>
# <div id="d3flux011_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux011model = {"metabolites": [{"id": "icit_6", "name": "icit", "compartment": "", "notes": {"map_info": {"display_name": "icit_6"}}}, {"id": "cit_6", "name": "cit", "compartment": "", "notes": {"map_info": {"display_name": "cit_6"}}}, {"id": "cit_m_6", "name": "cit_m", "compartment": "", "notes": {"map_info": {"display_name": "cit_m_6"}}}, {"id": "co2_1", "name": "co", "compartment": "", "notes": {"map_info": {"display_name": "co2_1"}}}, {"id": "co2_e_1", "name": "co2_e", "compartment": "", "notes": {"map_info": {"display_name": "co2_e_1"}}}, {"id": "co2_m_1", "name": "co2_m", "compartment": "", "notes": {"map_info": {"display_name": "co2_m_1"}}}, {"id": "accoa_m_1", "name": "accoa_m", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "accoa_m_1"}}}, {"id": "pep_2", "name": "pep", "compartment": "", "notes": {"map_info": {"display_name": "pep_2"}}}, {"id": "2pg_2", "name": "2pg", "compartment": "", "notes": {"map_info": {"display_name": "2pg_2"}}}, {"id": "glc-D_e_2", "name": "glc-D_e", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_e_2"}}}, {"id": "fdp_2", "name": "fdp", "compartment": "", "notes": {"map_info": {"display_name": "fdp_2"}}}, {"id": "g3p_2", "name": "g3p", "compartment": "", "notes": {"map_info": {"display_name": "g3p_2"}}}, {"id": "mal-L_1", "name": "mal-L", "compartment": "", "notes": {"map_info": {"display_name": "mal-L_1"}}}, {"id": "fum_1", "name": "fum", "compartment": "", "notes": {"map_info": {"display_name": "fum_1"}}}, {"id": "13dpg_2", "name": "13dpg", "compartment": "", "notes": {"map_info": {"display_name": "13dpg_2"}}}, {"id": "glc-D_2", "name": "glc-D", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_2"}}}, {"id": "g6p_2", "name": "g6p", "compartment": "", "notes": {"map_info": {"display_name": "g6p_2"}}}, {"id": "succ_1", "name": "succ", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "succ_1"}}}, {"id": "oaa_1", "name": "oaa", "compartment": "", "notes": {"map_info": {"display_name": "oaa_1"}}}, {"id": "pyr_m_2", "name": "pyr_m", "compartment": "", "notes": {"map_info": {"display_name": "pyr_m_2"}}}, {"id": "pyr_m_1", "name": "pyr_m", "compartment": "", "notes": {"map_info": {"display_name": "pyr_m_1"}}}, {"id": "f6p_2", "name": "f6p", "compartment": "", "notes": {"map_info": {"display_name": "f6p_2"}}}, {"id": "3pg_2", "name": "3pg", "compartment": "", "notes": {"map_info": {"display_name": "3pg_2"}}}, {"id": "pep_1", "name": "pep", "compartment": "", "notes": {"map_info": {"display_name": "pep_1"}}}, {"id": "pyr_2", "name": "pyr", "compartment": "", "notes": {"map_info": {"display_name": "pyr_2"}}}, {"id": "pyr_1", "name": "pyr", "compartment": "", "notes": {"map_info": {"display_name": "pyr_1"}}}, {"id": "succ_m_1", "name": "succ_m", "compartment": "", "notes": {"map_info": {"display_name": "succ_m_1"}}}, {"id": "fum_m_1", "name": "fum_m", "compartment": "", "notes": {"map_info": {"display_name": "fum_m_1"}}}], "reactions": [{"id": "ACONT_f_19", "name": "", "metabolites": {"cit_6": -1, "icit_6": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CITtam_b_21", "name": "", "metabolites": {"cit_6": 1, "cit_m_6": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2t_b_0", "name": "", "metabolites": {"co2_1": -1, "co2_e_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2tm_b_0", "name": "", "metabolites": {"co2_1": 1, "co2_m_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CSm_2", "name": "", "metabolites": {"accoa_m_1": -1, "cit_m_6": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_in ...
# ### EMU Pathway EM6 (glc-D_e_1 --> co2_e_1)
# <div id="d3flux012">
#
# </div>
# <div id="d3flux012_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux012model = {"metabolites": [{"id": "6pgl_1", "name": "6pgl", "compartment": "", "notes": {"map_info": {"display_name": "6pgl_1"}}}, {"id": "6pgl_r_1", "name": "6pgl_r", "compartment": "", "notes": {"map_info": {"display_name": "6pgl_r_1"}}}, {"id": "co2_1", "name": "co", "compartment": "", "notes": {"map_info": {"display_name": "co2_1"}}}, {"id": "co2_e_1", "name": "co2_e", "compartment": "", "notes": {"map_info": {"display_name": "co2_e_1"}}}, {"id": "glc-D_e_1", "name": "glc-D_e", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_e_1"}}}, {"id": "g6p_r_1", "name": "g6p_r", "compartment": "", "notes": {"map_info": {"display_name": "g6p_r_1"}}}, {"id": "g6p_1", "name": "g6p", "compartment": "", "notes": {"map_info": {"display_name": "g6p_1"}}}, {"id": "glc-D_1", "name": "glc-D", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "glc-D_1"}}}, {"id": "6pgc_1", "name": "6pgc", "compartment": "", "notes": {"map_info": {"flux": 1.0, "display_name": "6pgc_1"}}}], "reactions": [{"id": "6PGLter_b_8", "name": "", "metabolites": {"6pgl_1": 1, "6pgl_r_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "CO2t_b_0", "name": "", "metabolites": {"co2_1": -1, "co2_e_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "EX_co2_e_1", "name": "", "metabolites": {"co2_e_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "EX_glc-D_e_1", "name": "", "metabolites": {"glc-D_e_1": 1}, "lower_bound": 0, "upper_bound": 10, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "hidden": true, "reversibility": false}}}, {"id": "G6PDH2er_9", "name": "", "metabolites": {"6pgl_r_1": 1, "g6p_r_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "G6Pter_f_11", "name": "", "metabolites": {"g6p_1": -1, "g6p_r_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "GLCt1_6", "name": "", "metabolites": {"glc-D_1": 1, "glc-D_e_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "GND_5", "name": "", "metabolites": {"6pgc_1": -1, "co2_1": 1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "HEX1_6", "name": "", "metabolites": {"g6p_1": 1, "glc-D_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}, {"id": "PGL_10", "name": "", "metabolites": {"6pgc_1": 1, "6pgl_1": -1}, "lower_bound": 0, "upper_bound": 1000, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 1.0, "reversibility": false}}}], "genes": [], "id": "EM6", "compartments": {"": ""}, "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     d3: "https://d3js.org/d3.v3.min",
#     cola: "http://marvl.infotech.monash.edu/webcola/cola.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#   },
#   shim: {
#     'cola': {
#       exports: 'cola'
#     }
#   }
# });
#
# require(["cola", "d3", "math", "FileSaver"], function (cola, d3, math, FileSaver) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 1028,
#     height = 768;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       // .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#       //         "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .range(["#bbb", "#d62728",
#         "#eb6a9b",
#         "#6f3589",
#         "#f18572",
#         "#246035",
#         "#009fea",
#         "#83522b",
#         "#29378a",
#         "#989033"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = cola.d3adaptor()
#       .linkDistance(30)
#       .size([width, height]);
#     // var force = d3.layout.force()
#     //   .linkDistance(30)
#     //   .charge(-100)
#     //   .chargeDistance(400)
#     //   .gravity(.015)
#     //   .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux012").append("svg")
#         .attr("viewBox", "0 0 1028 768")
#         .attr("style", "display:block;margin:auto;width:100%");
#     } else {
#       var svg = d3.select("#d3flux012").select("svg");
#     }
#
#     // Append the CSS styles
#     svg.append("style").text(".node.rxn{fill:#ffa319}.node.rxn.hidden{fill:none;stroke:none;stroke-width:0}.link{fill:none;stroke-linecap:round}text.nodelabel{font-size:12pt;fill:#555;font-family:Arial}text.nodelabel.cofactor{font-size:9.6pt;fill:#789}text.nodelabel.rxn{fill:#a9a9a9;font-size:9.6pt;font-style:italic}marker.inactive,.node.inactive,text.inactive{fill-opacity:1.0}.link.inactive{stroke-opacity:1.0}");
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux012_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux012_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       e.setAttribute('src', 'https://rawgit.com/pstjohn/svg-crowbar/gh-pages/svg-crowbar.js');
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reac
